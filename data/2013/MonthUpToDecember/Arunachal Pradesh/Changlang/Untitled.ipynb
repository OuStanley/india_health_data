# %%
import pandas as pd
changlang = pd.read_html('ALL.xls')[0]
changlang
# Out:
#                                          Indicators  \
#   Total number of pregnant women Registered for ANC
#                                             2013-14
# 0                                               NaN
# 1                                               1.0
# 2                                               2.0
# 3                                               3.0
# 4                                               4.0
# 5                                               5.0
# 6                                               6.0
# 7                                               7.0
# 8                                               8.0
#
#                                                            1  \
#   Number of Pregnant women registered within first trimester
#                                                      2012-13
# 0                                         _Changlang
# 1                                           Bordumsa
# 2                                          Changlang
# 3                                              Diyun
# 4                                          Imaginary
# 5                                          Jairampur
# 6                                          Khimiyang
# 7                                               Miao
# 8                                            Nampong
#
#                                      2  \
#   Number of Women registered under JSY
#                                2013-14
# 0                               3166.0
# 1                                546.0
# 2                                778.0
# 3                                781.0
# 4                                  NaN
# 5                                166.0
# 6                                 66.0
# 7                                746.0
# 8                                 83.0
#
#                                                         3  \
#   % 1st Trimester registration to Total ANC Registrations
#                                                   2012-13
# 0                                             2896.0
# 1                                              474.0
# 2                                              710.0
# 3                                              736.0
# 4                                                NaN
# 5                                              177.0
# 6                                               48.0
# 7                                              665.0
# 8                                               86.0
#
#                                              4  \
#   % JSY registration to Total ANC Registration
#                                        2013-14
# 0                                        656.0
# 1                                         60.0
# 2                                        244.0
# 3                                        132.0
# 4                                          NaN
# 5                                         26.0
# 6                                         30.0
# 7                                        153.0
# 8                                         11.0
#
#                                                   5  \
#   Number of pregnant women received 3 ANC check ups
#                                             2012-13
# 0                                             619.0
# 1                                             113.0
# 2                                             213.0
# 3                                             107.0
# 4                                               NaN
# 5                                              56.0
# 6                                              21.0
# 7                                             102.0
# 8                                               7.0
#
#                                                  6  \
#   TT2 or Booster given to Pregnant women (numbers)
#                                            2013-14
# 0                                           2235.0
# 1                                            461.0
# 2                                            425.0
# 3                                            376.0
# 4                                              NaN
# 5                                            161.0
# 6                                             62.0
# 7                                            682.0
# 8                                             68.0
#
#                                                                      7  \
#   % Pregnant Woman received 3 ANC check ups to Total ANC Registrations
#                                                                2012-13
# 0                                             2348.0
# 1                                              420.0
# 2                                              525.0
# 3                                              514.0
# 4                                                NaN
# 5                                              176.0
# 6                                               43.0
# 7                                              590.0
# 8                                               80.0
#
#                                                                    8  \
#   % Pregnant women received TT2 or Booster to Total ANC Registration
#                                                              2013-14
# 0                                               20.7
# 1                                               11.0
# 2                                               31.4
# 3                                               16.9
# 4                                                NaN
# 5                                               15.7
# 6                                               45.5
# 7                                               20.5
# 8                                               13.3
#
#                                                9         ...           \
#   Number of Pregnant women given 100 IFA tablets         ...
#                                          2012-13         ...
# 0                                           21.3         ...
# 1                                           23.8         ...
# 2                                           30.0         ...
# 3                                           14.5         ...
# 4                                            NaN         ...
# 5                                           31.6         ...
# 6                                           43.8         ...
# 7                                           15.3         ...
# 8                                            8.1         ...
#
#   Unnamed: 316_level_0 Unnamed: 317_level_0 Unnamed: 318_level_0  \
#   Unnamed: 316_level_1 Unnamed: 317_level_1 Unnamed: 318_level_1
#                2013-14              2012-13              2013-14
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# 5                  NaN                  NaN                  NaN
# 6                  NaN                  NaN                  NaN
# 7                  NaN                  NaN                  NaN
# 8                  NaN                  NaN                  NaN
#
#   Unnamed: 319_level_0 Unnamed: 320_level_0 Unnamed: 321_level_0  \
#   Unnamed: 319_level_1 Unnamed: 320_level_1 Unnamed: 321_level_1
#                2012-13              2013-14              2012-13
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# 5                  NaN                  NaN                  NaN
# 6                  NaN                  NaN                  NaN
# 7                  NaN                  NaN                  NaN
# 8                  NaN                  NaN                  NaN
#
#   Unnamed: 322_level_0 Unnamed: 323_level_0 Unnamed: 324_level_0  \
#   Unnamed: 322_level_1 Unnamed: 323_level_1 Unnamed: 324_level_1
#                2013-14              2012-13 Unnamed: 324_level_2
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# 5                  NaN                  NaN                  NaN
# 6                  NaN                  NaN                  NaN
# 7                  NaN                  NaN                  NaN
# 8                  NaN                  NaN                  NaN
#
#   Unnamed: 325_level_0
#   Unnamed: 325_level_1
#   Unnamed: 325_level_2
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
#
# [9 rows x 326 columns]

# %%
changlang = pd.read_html('ALL.xls')[0]
changlang.columns = changlang.columns.get_level_values(1)

changlang = (changlang
 .rename(columns={'Number of Pregnant women registered within first trimester':'2013-2014 MonthUpToDecember Subdistrict Name'})
 .set_index('2013-2014 MonthUpToDecember Subdistrict Name')
 .iloc[1:10, :]
)
changlang
# Out:
#                                               Total number of pregnant women Registered for ANC  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                    1.0
# Changlang                                                                                   2.0
# Diyun                                                                                       3.0
# Imaginary                                                                                   4.0
# Jairampur                                                                                   5.0
# Khimiyang                                                                                   6.0
# Miao                                                                                        7.0
# Nampong                                                                                     8.0
#
#                                               Number of Women registered under JSY  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                     546.0
# Changlang                                                                    778.0
# Diyun                                                                        781.0
# Imaginary                                                                      NaN
# Jairampur                                                                    166.0
# Khimiyang                                                                     66.0
# Miao                                                                         746.0
# Nampong                                                                       83.0
#
#                                               % 1st Trimester registration to Total ANC Registrations  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                  474.0
# Changlang                                                                                 710.0
# Diyun                                                                                     736.0
# Imaginary                                                                                   NaN
# Jairampur                                                                                 177.0
# Khimiyang                                                                                  48.0
# Miao                                                                                      665.0
# Nampong                                                                                    86.0
#
#                                               % JSY registration to Total ANC Registration  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                              60.0
# Changlang                                                                            244.0
# Diyun                                                                                132.0
# Imaginary                                                                              NaN
# Jairampur                                                                             26.0
# Khimiyang                                                                             30.0
# Miao                                                                                 153.0
# Nampong                                                                               11.0
#
#                                               Number of pregnant women received 3 ANC check ups  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                  113.0
# Changlang                                                                                 213.0
# Diyun                                                                                     107.0
# Imaginary                                                                                   NaN
# Jairampur                                                                                  56.0
# Khimiyang                                                                                  21.0
# Miao                                                                                      102.0
# Nampong                                                                                     7.0
#
#                                               TT2 or Booster given to Pregnant women (numbers)  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                 461.0
# Changlang                                                                                425.0
# Diyun                                                                                    376.0
# Imaginary                                                                                  NaN
# Jairampur                                                                                161.0
# Khimiyang                                                                                 62.0
# Miao                                                                                     682.0
# Nampong                                                                                   68.0
#
#                                               % Pregnant Woman received 3 ANC check ups to Total ANC Registrations  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                  420.0
# Changlang                                                                                 525.0
# Diyun                                                                                     514.0
# Imaginary                                                                                   NaN
# Jairampur                                                                                 176.0
# Khimiyang                                                                                  43.0
# Miao                                                                                      590.0
# Nampong                                                                                    80.0
#
#                                               % Pregnant women received TT2 or Booster to Total ANC Registration  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                   11.0
# Changlang                                                                                  31.4
# Diyun                                                                                      16.9
# Imaginary                                                                                   NaN
# Jairampur                                                                                  15.7
# Khimiyang                                                                                  45.5
# Miao                                                                                       20.5
# Nampong                                                                                    13.3
#
#                                               Number of Pregnant women given 100 IFA tablets  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                23.8
# Changlang                                                                               30.0
# Diyun                                                                                   14.5
# Imaginary                                                                                NaN
# Jairampur                                                                               31.6
# Khimiyang                                                                               43.8
# Miao                                                                                    15.3
# Nampong                                                                                  8.1
#
#                                               % Pregnant women given 100 IFA to Total ANC Registration  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                                                   84.4
# Changlang                                                                                  54.6
# Diyun                                                                                      48.1
# Imaginary                                                                                   NaN
# Jairampur                                                                                  97.0
# Khimiyang                                                                                  93.9
# Miao                                                                                       91.4
# Nampong                                                                                    81.9
#
#                                                       ...           \
# 2013-2014 MonthUpToDecember Subdistrict Name          ...
# Bordumsa                                              ...
# Changlang                                             ...
# Diyun                                                 ...
# Imaginary                                             ...
# Jairampur                                             ...
# Khimiyang                                             ...
# Miao                                                  ...
# Nampong                                               ...
#
#                                               Unnamed: 316_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 317_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 318_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 319_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 320_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 321_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 322_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 323_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 324_level_1  \
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
#                                               Unnamed: 325_level_1
# 2013-2014 MonthUpToDecember Subdistrict Name
# Bordumsa                                                       NaN
# Changlang                                                      NaN
# Diyun                                                          NaN
# Imaginary                                                      NaN
# Jairampur                                                      NaN
# Khimiyang                                                      NaN
# Miao                                                           NaN
# Nampong                                                        NaN
#
# [8 rows x 325 columns]

# %%
changlang.to_csv('/Users/stanleyou/india_health_data/csv/changlang.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-fdca16804be7> in <module>()
# ----> 1 pd.read_csv('/Users/stanleyou/india_health_data/csv/changlang2013-2014.csv', index_col='2013-2014 MonthUpToDecember Subdistrict Name')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'/Users/stanleyou/india_health_data/csv/changlang2013-2014.csv' does not exist
