# %%
import pandas as pd

# %%
anjaw = pd.read_html('ALL.xls')[0]
anjaw
# Out:
#                                          Indicators  \
#   Total number of pregnant women Registered for ANC
#                                             2012-13
# 0                                               NaN
# 1                                               1.0
# 2                                               2.0
# 3                                               3.0
#
#                                                            1  \
#   Number of Pregnant women registered within first trimester
#                                                      2012-13
# 0                                             _Anjaw
# 1                                          Chaglagam
# 2                                       Hawai-Walong
# 3                                          Hayuliang
#
#                                      2  \
#   Number of Women registered under JSY
#                                2012-13
# 0                                  345
# ...

# %%
anjaw = pd.read_html('ALL.xls')[0]
anjaw.columns = anjaw.columns.get_level_values(1)

(anjaw
 .rename(columns={'Number of Pregnant women registered within first trimester':'2012-2013 MonthUpToDecember Subdistrict Name'})
 .set_index('2012-2013 MonthUpToDecember Subdistrict Name')
 .iloc[1:4, :]  
 
)
# Out:
#                                               Total number of pregnant women Registered for ANC  \
# 2012-2013 MonthUpToDecember Subdistrict Name
# Chaglagam                                                                                   1.0
# Hawai-Walong                                                                                2.0
# Hayuliang                                                                                   3.0
#
#                                               Number of Women registered under JSY  \
# 2012-2013 MonthUpToDecember Subdistrict Name
# Chaglagam                                                                       18
# Hawai-Walong                                                                    97
# Hayuliang                                                                      230
#
#                                               % 1st Trimester registration to Total ANC Registrations  \
# 2012-2013 MonthUpToDecember Subdistrict Name
# ...

# %%
list(anjaw.columns)
# Out:
# ['Total number of pregnant women Registered for ANC',
#  'Number of Pregnant women registered within first trimester',
#  'Number of Women registered under JSY',
#  '% 1st Trimester registration to Total ANC Registrations',
#  '% JSY registration to Total ANC Registration',
#  'Number of pregnant women received 3 ANC check ups',
#  'TT2 or Booster given to Pregnant women (numbers)',
#  '% Pregnant Woman received 3 ANC check ups to Total ANC Registrations',
#  '% Pregnant women received TT2 or Booster to Total ANC Registration',
#  'Number of Pregnant women given 100 IFA tablets',
#  '% Pregnant women given 100 IFA to Total ANC Registration',
#  'Number having Hb level<11 (tested cases)',
#  'Number having severe anaemia (Hb<7) treated at institution',
#  '% Pregnant women having severe anaemia (Hb<7) treated at institution to women having hb level<11',
#  '% New cases detected at institution for hypertension to Total ANC Registrations',
#  'Number of Home deliveries',
# ...
