# %%
import pandas as pd

# %%
changlang_2012 = pd.read_csv('changlang.csv')
changlang_2012.head()
# Out:
#   2012-2013 MonthUpToDecember Subdistrict Name  \
# 0                                     Bordumsa
# 1                                    Changlang
# 2                                        Diyun
# 3                                    Imaginary
# 4                                    Jairampur
#
#    Total number of pregnant women Registered for ANC  \
# 0                                                1.0
# 1                                                2.0
# 2                                                3.0
# 3                                                4.0
# 4                                                5.0
#
#    Number of Women registered under JSY  \
# 0                                 474.0
# 1                                 710.0
# 2                                 736.0
# 3                                   NaN
# 4                                 177.0
#
#    % 1st Trimester registration to Total ANC Registrations  \
# ...

# %%
district_names = changlang_2012['2012-2013 MonthUpToDecember Subdistrict Name']

# %%
changlang_2013 = pd.read_csv('changlang2013-2014.csv')
changlang_2013.head()
# Out:
#   2013-2014 MonthUpToDecember Subdistrict Name  \
# 0                                     Bordumsa
# 1                                    Changlang
# 2                                        Diyun
# 3                                    Imaginary
# 4                                    Jairampur
#
#    Total number of pregnant women Registered for ANC  \
# 0                                                1.0
# 1                                                2.0
# 2                                                3.0
# 3                                                4.0
# 4                                                5.0
#
#    Number of Women registered under JSY  \
# 0                                 546.0
# 1                                 778.0
# 2                                 781.0
# 3                                   NaN
# 4                                 166.0
#
#    % 1st Trimester registration to Total ANC Registrations  \
# ...

# %%
test = changlang_2012.add(changlang_2013).add(changlang_2012)
test['2012-2014 Subdistrict Name'] = district_names
test.set_index('2012-2014 Subdistrict Name')
# Out:
#                             % 1st Trimester registration to Total ANC Registrations  \
# 2012-2014 Subdistrict Name
# Bordumsa                                                                700.0
# Changlang                                                              1136.0
# Diyun                                                                   950.0
# Imaginary                                                                 NaN
# Jairampur                                                               289.0
# Khimiyang                                                                90.0
# Miao                                                                    869.0
# Nampong                                                                 100.0
#
#                             % AYUSH OPD to Total OPD  \
# 2012-2014 Subdistrict Name
# Bordumsa                                         0.0
# Changlang                                        NaN
# ...
